# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a micro web framework written in Python. It is classified as a microframework because it does not require particular tools or libraries. It has no database abstraction layer, form validation, or any other components where pre-existing third-party libraries provide common functions.

# %% [markdown]
# The primary advantages of choosing Flask are built-in fast debugger, secure cookies and unit testing support, Unicode basis, and more. The framework allows developers to decide how exactly to build the application needed.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)


@app.route("/")
def hello_world():
    return "<h1>Hello world<h2>"

if __name__=="__main__":
    app.run()

# %% [markdown]
# ![image.png](attachment:cfcdec16-f0c4-4e19-beb9-cbb67a66c522.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page like Flask in the web application.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
#
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)


@app.route("/")
def details():
    cn = "ABC Corporation"
    l = "India"
    c = "999-999-9999"
    return "Company Name: {} \nLocation: {} \nContact Detail: {}".format(cn,l,c)

@app.route("/Welcome")
def hello_world():
    return "Welcome to ABC Corporation"

if __name__=="__main__":
    app.run()

# %% [markdown]
# ![image.png](attachment:ad9d8758-f3e0-4350-8c16-769611122972.png)

# %% [markdown]
# ![image.png](attachment:284d1077-6330-4f02-a8ac-c98f38da6e1c.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# The url_for() function is used to build a URL to the specific function dynamically. The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL.
#
# This function is useful in the sense that we can avoid hard-coding the URLs into the templates by dynamically building them using this function.

# %%
from flask import Flask, redirect, url_for

app = Flask(__name__)  
  
@app.route('/admin')  
def admin():  
    return 'admin'  
  
@app.route('/librarion')  
def librarion():  
    return 'librarion'  
  
@app.route('/student')  
def student():  
    return 'student'  
  
@app.route('/user/<name>')  
def user(name):  
    if name == 'admin':  
        return redirect(url_for('admin'))  
    if name == 'librarion':  
        return redirect(url_for('librarion'))  
    if name == 'student':  
        return redirect(url_for('student'))  


if __name__ =='__main__':  
    app.run()
